# %% [markdown]
# <a href="https://colab.research.google.com/github/BF667/midi-composer/blob/main/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # midi composer

# %%
#@title setup env

# %%capture

# !git clone https://github.com/BF667/midi-composer.git
# %cd midi-composer
# !apt install fluidsynth
# !uv pip install -r requirements.txt

# %% [markdown]
# ## run

# %%
# !python app.py --max-gen 4096 --share
